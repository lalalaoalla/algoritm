# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В общем задача то не сложная, ОДНАКО БЫЛА ПРОБЛЕМА С ВОЗВРАЩЕНИЕМ СПИСКА А В ИТОГЕ ОКАЗАЛОСЬ ЕГО И ВОЗВРАЩАТЬ НЕ НАДО

# %%
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        k = len(nums)
        if val not in nums:
            return k
        else:
            for i in range(len(nums)-1,-1,-1):
                if nums[i] == val:
                    nums[i] = '_'
                    nums.append(nums.pop(i))
                    k-=1
            return k

nums = [0,1,2,2,3,0,4,2]
val = 2

solution = Solution()
#k, nums = solution.removeElement(nums, val)

print(k, nums)
# Out:
# 5 [0, 1, 3, 0, 4, '_', '_', '_']

# %%
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        k = len(nums)
        j = 0
        #if val not in nums: # эта проверка не нужна, просто проходим по всему массиву
        #    return k, nums

        for i in range(len(nums)-1,-1,-1):
            if nums[i] == val:
                nums[i] = -1
                nums.append(nums.pop(i)) # Перемещаем в конец
                k-=1
        return k, nums

nums = [0,1,2,2,3,0,4,2]
val = 2

solution = Solution()
k, nums = solution.removeElement(nums, val)

print(k, nums)
# Out:
# 5 [0, 1, 3, 0, 4, '_', '_', '_']
